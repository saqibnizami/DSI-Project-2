# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from sklearn.linear_model import LogisticRegressionCV, RidgeCV, LassoCV, LassoLarsCV
from sklearn.preprocessing import StandardScaler, LabelBinarizer, LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import cross_val_score, train_test_split, RandomizedSearchCV
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

lb = LabelBinarizer
le = LabelEncoder

# %%
d = pd.read_csv("datadict.csv")

# %%
# on x row and
# Out:
#                                             SalePrice   \
# 0                                           MSSubClass
# 1                   20 1-STORY 1946 & NEWER ALL STYLES
# 2                              30 1-STORY 1945 & OLDER
# 3                 40 1-STORY W/FINISHED ATTIC ALL AGES
# 4                 45 1-1/2 STORY - UNFINISHED ALL AGES
# 5                     50 1-1/2 STORY FINISHED ALL AGES
# 6                              60 2-STORY 1946 & NEWER
# 7                              70 2-STORY 1945 & OLDER
# 8                              75 2-1/2 STORY ALL AGES
# 9                              80 SPLIT OR MULTI-LEVEL
# 10                                      85 SPLIT FOYER
# 11                     90 DUPLEX - ALL STYLES AND AGES
# 12   120 1-STORY PUD (Planned Unit Development) - 1...
# 13                      150 1-1/2 STORY PUD - ALL AGES
# 14                      160 2-STORY PUD - 1946 & NEWER
# 15         180 PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
# 16       190 2 FAMILY CONVERSION - ALL STYLES AND AGES
# 17                                            MSZoning
# 18                                       A Agriculture
# 19                                        C Commercial
# 20                     FV Floating Village Residential
# 21                                        I Industrial
# 22                         RH Residential High Density
# 23                          RL Residential Low Density
# 24                     RP Residential Low Density Park
# 25                       RM Residential Medium Density
# 26                                         LotFrontage
# 27                                             LotArea
# 28                                              Street
# 29                                         Grvl Gravel
# ..                                                 ...
# 363                                            Fa Fair
# 364                                         NA No Pool
# 365                                              Fence
# 366                                 GdPrv Good Privacy
# 367                              MnPrv Minimum Privacy
# 368                                     GdWo Good Wood
# 369                             MnWw Minimum Wood/Wire
# 370                                        NA No Fence
# 371                                        MiscFeature
# 372                                      Elev Elevator
# 373  Gar2 2nd Garage (if not described in garage se...
# 374                                         Othr Other
# 375                            Shed Shed (over 100 SF)
# 376                                  TenC Tennis Court
# 377                                            NA None
# 378                                            MiscVal
# 379                                             MoSold
# 380                                             YrSold
# 381                                           SaleType
# 382                    WD Warranty Deed - Conventional
# 383                           CWD Warranty Deed - Cash
# 384                        VWD Warranty Deed - VA Loan
# 385                 New Home just constructed and sold
# 386                      COD Court Officer Deed/Estate
# 387        Con Contract 15% Down payment regular terms
# 388   ConLw Contract Low Down payment and low interest
# 389                        ConLI Contract Low Interest
# 390                            ConLD Contract Low Down
# 391                                          Oth Other
# 392                                                NaN
#
#     the property's sale price in dollars. This is the target variable that you're trying to predict for this challenge.
# 0                                   The building class
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17    Identifies the general zoning classification ...
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26         Linear feet of street connected to property
# 27                             Lot size in square feet
# 28                     Type of road access to property
# 29                                                 NaN
# ..                                                 ...
# 363                                                NaN
# 364                                                NaN
# 365                                      Fence quality
# 366                                                NaN
# 367                                                NaN
# 368                                                NaN
# 369                                                NaN
# 370                                                NaN
# 371   Miscellaneous feature not covered in other ca...
# 372                                                NaN
# 373                                                NaN
# 374                                                NaN
# 375                                                NaN
# 376                                                NaN
# 377                                                NaN
# 378                    $Value of miscellaneous feature
# 379                                         Month Sold
# 380                                          Year Sold
# 381                                       Type of sale
# 382                                                NaN
# 383                                                NaN
# 384                                                NaN
# 385                                                NaN
# 386                                                NaN
# 387                                                NaN
# 388                                                NaN
# 389                                                NaN
# 390                                                NaN
# 391                                                NaN
# 392                                                NaN
#
# [393 rows x 2 columns]
